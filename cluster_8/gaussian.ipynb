# %%
# !pip instal tifffile

# %%
import matplotlib.pyplot as plt
import tifffile

flattened_image = tifffile.imread("image_flattened.tif")

plt.imshow(flattened_image, cmap='gray')
plt.colorbar()
plt.show()
